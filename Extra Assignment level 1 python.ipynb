# %%
print('HOPE AI')
# Out:
# HOPE AI

# %%
input('Enter your institute name?:')
# Out:
# Enter your institute name?: HOPE AI
# 'HOPE AI'

# %%
input('Enter your name:')
input('Enter your age:')
input('Enter your school name:')
input('Enter your degree:')
# Out:
# Enter your name: Khavya
# Enter your age: 20
# Enter your school name: The Ashok Leyland School
# Enter your degree: B.E ECE
# 'B.E ECE'

# %%
#addition
a=43
b=34
print('a=',a,'\n','b=',b,'\n','add',a+b)
# Out:
# a= 43
#  b= 34
#  add 77

# %%
#subtraction
a=43
b=34
print('a=', a, '\n''b=', b, '\n''sub',a-b)
# Out:
# a= 43
# b= 34
# sub 9

# %%
#multiplication
a=63
b=97
print('a=', a, '\n''b=', b, '\n''mul',a*b)
# Out:
# a= 63
# b= 97
# mul 6111

# %%
#Division
a=76
b=31
print('a=', a, '\n''b=', b, '\n''Float Div',a/b)
# Out:
# a= 76
# b= 31
# Float Div 2.4516129032258065

# %%
#Floor division
a=76
b=31
print('a=', a, '\n''b=', b, '\n''Floor Div',a//b)
# Out:
# a= 76
# b= 31
# Floor Div 2

# %%
#subtraction
a=43
b=34
print('a=', a, '\n''b=', b, '\n''sub',a-b)
