# %%
 # Create a class and function, and list out the items in the list

class SubfieldsInAI():
    def Subfields(self):
        print('Sub-fields in AI are:')
        lst=['Machine Learning','Neural Networks','Vision','Robotics','Speech Processing','Natural Languange Processing']
        for i in lst:
            print(i)

obj=SubfieldsInAI()
obj.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Languange Processing

# %%
class OddEven():
    def OddEvenNo(self):
        num=int(input('Enter a number:'))
        if num%2==0:
            return f'{num} is even number'
        else:
            return f'{num} is odd number'

OddEven=OddEven()
print(OddEven.OddEvenNo())
# Out:
# Enter a number: 52452
# 52452 is even number

# %%
class ElegiblityForMarriage():
    def Elegible(self):
        gender=input('Your Gender:')
        age=int(input('Your Age:'))
        if gender=='Female':
            if age>17:
                return 'ELIGIBLE'
            else:
                return 'NOT ELIGIBLE'
        elif gender=='Male':
            if age>20:
                return 'ELIGIBLE'
            else:
                return 'NOT ELIGIBLE'

ElegiblityForMarriage=ElegiblityForMarriage()
print(ElegiblityForMarriage.Elegible())
# Out:
# Your Gender: Female
# Your Age: 23
# ELIGIBLE

# %%
class FindPercent:
    def percentage(self):
        s1 = int(input("Subject1= "))
        s2 = int(input("Subject2= "))
        s3 = int(input("Subject3= "))
        s4 = int(input("Subject4= "))
        s5 = int(input("Subject5= "))

        total = s1 + s2 + s3 + s4 + s5
        percent = (total / 500) * 100

        print( "Total :", total)
        print( "Percentage :", percent)

FindPercent=FindPercent()
FindPercent.percentage()
# Out:
# Subject1=  98
# Subject2=  87
# Subject3=  95
# Subject4=  95
# Subject5=  93
# Total : 468
# Percentage : 93.60000000000001

# %%
class triangle:
    def triangle(self):
        h = float(input("Height:"))
        b = float(input("Breadth:"))
        print("Area formula: (Height*Breadth)/2")
        area = (h * b) / 2
        print("Area of Triangle:", area)

        h1 = float(input("Height1:"))
        h2 = float(input("Height2:"))
        b2 = float(input("Breadth:"))
        print("Perimeter formula: Height1+Height2+Breadth")
        peri = h1 + h2 + b2
        print("Perimeter of Triangle:", peri)

triangle=triangle()
triangle.triangle()
# Out:
# Height: 32
# Breadth: 34
# Area formula: (Height*Breadth)/2
# Area of Triangle: 544.0
# Height1: 2
# Height2: 4
# Breadth: 4
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle: 10.0
