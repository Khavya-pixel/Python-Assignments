# %%
#Categorize Transaction Amount

amount = float(input("Enter the transaction amount: "))

if amount > 0:
    print("Positive amount")
elif amount < 0:
    print("Negative amount")
else:
    print("Zero amount")
# Out:
# Enter the transaction amount: 5000000
# Positive amount

# %%
#Sum of Digits of a Number

num = int(input("Enter a number: "))
sum_digits = 0
temp = num

while temp > 0:
    sum_digits += temp % 10
    temp //= 10

print("Sum of digits:", sum_digits)
# Out:
# Enter a number: 52
# Sum of digits: 7

# %%
#Reverse a Number

num = int(input("Enter a number: "))
reverse = 0
temp = num

while temp > 0:
    reverse = reverse * 10 + temp % 10
    temp //= 10

print("Reversed number:", reverse)
# Out:
# Enter a number: 95486
# Reversed number: 68459

# %%
#Check if a Number is Prime

num = int(input("Enter a number: "))

if num > 1:
    for i in range(2, num):
        if num % i == 0:
            print(num, "is not prime")
            break
    else:
        print(num, "is prime")
else:
    print(num, "is not prime")
# Out:
# Enter a number: 563
# 563 is prime

# %%
#Factorial Using Recursion

def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n-1)

num = int(input("Enter a number: "))
print("Factorial:", factorial(num))
# Out:
# Enter a number: 9
# Factorial: 362880

# %%
#Check Armstrong Number

#(Armstrong number = sum of cubes of digits = number itself, for 3-digit numbers)

num = int(input("Enter a number: "))
sum_cubes = 0
temp = num

while temp > 0:
    digit = temp % 10
    sum_cubes += digit ** 3
    temp //= 10

if sum_cubes == num:
    print(num, "is an Armstrong number")
else:
    print(num, "is not an Armstrong number")
# Out:
# Enter a number: 8
# 8 is not an Armstrong number

# %%
#Swap First and Last Characters of a String

s = input("Enter a string: ")

if len(s) > 1:
    s = s[-1] + s[1:-1] + s[0]

print("Modified string:", s)
# Out:
# Enter a string: you
# Modified string: uoy

# %%
#Convert Decimal to Binary

num = int(input("Enter a decimal number: "))

binary = bin(num)[2:]  # bin() returns '0b...' so we slice [2:]
print("Binary equivalent:", binary)
# Out:
# Enter a decimal number: 9
# Binary equivalent: 1001

# %%
#Find the Longest Word in a Sentence

sentence = input("Enter a sentence: ")
words = sentence.split()

longest_word = max(words, key=len)
print("Longest word:", longest_word)
# Out:
# Enter a sentence: The concepts are interesting
# Longest word: interesting

# %%
#Check if Two Strings are Anagrams

str1 = input("Enter first string: ").replace(" ", "").lower()
str2 = input("Enter second string: ").replace(" ", "").lower()

if sorted(str1) == sorted(str2):
    print("Strings are anagrams")
else:
    print("Strings are not anagrams")
# Out:
# Enter first string: Younger generation
# Enter second string: future generation
# Strings are not anagrams
